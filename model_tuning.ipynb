# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
model= load_model("/content/drive/MyDrive/cdd_ironhack_p4/model.keras")
